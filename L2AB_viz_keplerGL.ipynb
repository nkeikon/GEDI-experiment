# %%
import pandas as pd
from keplergl import KeplerGl 
map_1 = KeplerGl()
# Out:
# User Guide: https://github.com/keplergl/kepler.gl/blob/master/docs/keplergl-jupyter/user-guide.md

# %%
file = 'https://raw.githubusercontent.com/nkeikon/GEDI-experiment/master/GEDI02_AB_2019118103533_O02121_T04316_02_001_01_BEAM1011.csv'
df = pd.read_csv(file)
df
# Out:
#               shot_number   Longitude   Latitude  height_bin0  rh100   rh90  \
# 0       21211100400074070 -112.129973  25.820920     3.025936   2.95   1.42
# 1       21211107800074107 -112.116152  25.835301    25.798561  21.20  17.79
# 2       21211108200074109 -112.115402  25.836079    37.147896  17.90  14.90
# 3       21211108400074110 -112.115027  25.836468    19.468002  14.38  12.09
# 4       21211108600074111 -112.114652  25.836858    17.933070  10.30   8.20
# ...                   ...         ...        ...          ...    ...    ...
# 139913  21211116400362366   48.620140 -17.289680     9.358141   9.25   5.69
# 139914  21211116600362367   48.620468 -17.290090    25.727953  15.09  10.86
# 139915  21211116800362368   48.620797 -17.290500    20.633543  20.15  14.19
# 139916  21211110200362456   48.649732 -17.326551     3.889171   3.74   1.57
# 139917  21211110400362457   48.650060 -17.326959    11.868034  11.35   8.27
#
# ...

# %%
config= {
  "version": "v1",
  "config": {
    "visState": {
      "filters": [{
        "dataId": "GEDI",
        "id": "iotomkece",
        "name": "Total canopy cover",
        "type": "range",
        "value": [0, 0.981],
        "enlarged": False,
        "plotType": "histogram",
        "yAxis": None
      }],
      "layers": [{
        "id": "ch1k4d",
        "type": "grid",
        "config": {
          "dataId": "GEDI",
          "label": "rh75",
          "color": [218, 112, 191],
          "columns": {
            "lat": "Latitude",
            "lng": "Longitude"
          },
          "isVisible": True,
          "visConfig": {
            "opacity": 0.5,
            "worldUnitSize": 0.025,
            "colorRange": {
              "name": "Custom Palette",
              "type": "custom",
              "category": "Custom",
              "colors": ["#900C3F"]
            },
            "coverage": 1,
            "sizeRange": [0, 500],
            "percentile": [0, 100],
            "elevationPercentile": [0, 100],
            "elevationScale": 10,
            "colorAggregation": "average",
            "sizeAggregation": "average",
            "enable3d": True
          },
          "textLabel": [{
            "field": None,
            "color": [255, 255, 255],
            "size": 18,
            "offset": [0, 0],
            "anchor": "start",
            "alignment": "center"
          }]
        },
        "visualChannels": {
          "colorField": {
            "name": "rh75",
            "type": "real"
          },
          "colorScale": "quantile",
          "sizeField": {
            "name": "rh75",
            "type": "real"
          },
          "sizeScale": "linear"
        }
      }, {
        "id": "j59qynv",
        "type": "grid",
        "config": {
          "dataId": "GEDI",
          "label": "rh80",
          "color": [34, 63, 154],
          "columns": {
            "lat": "Latitude",
            "lng": "Longitude"
          },
          "isVisible": True,
          "visConfig": {
            "opacity": 0.5,
            "worldUnitSize": 0.025,
            "colorRange": {
              "name": "Custom Palette",
              "type": "custom",
              "category": "Custom",
              "colors": ["#C70039"]
            },
            "coverage": 1,
            "sizeRange": [0, 500],
            "percentile": [0, 100],
            "elevationPercentile": [0, 100],
            "elevationScale": 10,
            "colorAggregation": "average",
            "sizeAggregation": "average",
            "enable3d": True
          },
          "textLabel": [{
            "field": None,
            "color": [255, 255, 255],
            "size": 18,
            "offset": [0, 0],
            "anchor": "start",
            "alignment": "center"
          }]
        },
        "visualChannels": {
          "colorField": {
            "name": "rh80",
            "type": "real"
          },
          "colorScale": "quantile",
          "sizeField": {
            "name": "rh80",
            "type": "real"
          },
          "sizeScale": "linear"
        }
      }, {
        "id": "5mfeho4n",
        "type": "grid",
        "config": {
          "dataId": "GEDI",
          "label": "rh90",
          "color": [241, 92, 23],
          "columns": {
            "lat": "Latitude",
            "lng": "Longitude"
          },
          "isVisible": True,
          "visConfig": {
            "opacity": 0.8,
            "worldUnitSize": 0.025,
            "colorRange": {
              "name": "Custom Palette",
              "type": "custom",
              "category": "Custom",
              "colors": ["#E3611C"]
            },
            "coverage": 1,
            "sizeRange": [0, 500],
            "percentile": [0, 100],
            "elevationPercentile": [0, 100],
            "elevationScale": 10,
            "colorAggregation": "average",
            "sizeAggregation": "average",
            "enable3d": True
          },
          "textLabel": [{
            "field": None,
            "color": [255, 255, 255],
            "size": 18,
            "offset": [0, 0],
            "anchor": "start",
            "alignment": "center"
          }]
        },
        "visualChannels": {
          "colorField": {
            "name": "rh90",
            "type": "real"
          },
          "colorScale": "quantile",
          "sizeField": {
            "name": "rh90",
            "type": "real"
          },
          "sizeScale": "linear"
        }
      }, {
        "id": "muakgrs",
        "type": "grid",
        "config": {
          "dataId": "GEDI",
          "label": "rh100",
          "color": [130, 154, 227],
          "columns": {
            "lat": "Latitude",
            "lng": "Longitude"
          },
          "isVisible": True,
          "visConfig": {
            "opacity": 0.8,
            "worldUnitSize": 0.025,
            "colorRange": {
              "name": "Custom Palette",
              "type": "custom",
              "category": "Custom",
              "colors": ["#F1920E"]
            },
            "coverage": 1,
            "sizeRange": [0, 500],
            "percentile": [0, 100],
            "elevationPercentile": [0, 100],
            "elevationScale": 10,
            "colorAggregation": "average",
            "sizeAggregation": "average",
            "enable3d": True
          },
          "textLabel": [{
            "field": None,
            "color": [255, 255, 255],
            "size": 18,
            "offset": [0, 0],
            "anchor": "start",
            "alignment": "center"
          }]
        },
        "visualChannels": {
          "colorField": {
            "name": "rh100",
            "type": "real"
          },
          "colorScale": "quantile",
          "sizeField": {
            "name": "rh100",
            "type": "real"
          },
          "sizeScale": "linear"
        }
      }, {
        "id": "5wrcqhn",
        "type": "grid",
        "config": {
          "dataId": "GEDI",
          "label": "Height_bin0",
          "color": [18, 147, 154],
          "columns": {
            "lat": "Latitude",
            "lng": "Longitude"
          },
          "isVisible": True,
          "visConfig": {
            "opacity": 0.5,
            "worldUnitSize": 0.025,
            "colorRange": {
              "name": "Custom Palette",
              "type": "custom",
              "category": "Custom",
              "colors": ["#FFC300"]
            },
            "coverage": 1,
            "sizeRange": [0, 500],
            "percentile": [0, 100],
            "elevationPercentile": [0, 100],
            "elevationScale": 10,
            "colorAggregation": "average",
            "sizeAggregation": "average",
            "enable3d": True
          },
          "textLabel": [{
            "field": None,
            "color": [255, 255, 255],
            "size": 18,
            "offset": [0, 0],
            "anchor": "start",
            "alignment": "center"
          }]
        },
        "visualChannels": {
          "colorField": {
            "name": "height_bin0",
            "type": "real"
          },
          "colorScale": "quantile",
          "sizeField": {
            "name": "height_bin0",
            "type": "real"
          },
          "sizeScale": "linear"
        }
      }, {
        "id": "25z9gom",
        "type": "heatmap",
        "config": {
          "dataId": "GEDI",
          "label": "Canopy cover",
          "color": [18, 147, 154],
          "columns": {
            "lat": "Latitude",
            "lng": "Longitude"
          },
          "isVisible": True,
          "visConfig": {
            "opacity": 0.8,
            "colorRange": {
              "name": "Global Warming",
              "type": "sequential",
              "category": "Uber",
              "colors": ["#5A1846", "#900C3F", "#C70039", "#E3611C", "#F1920E", "#FFC300"]
            },
            "radius": 20
          },
          "textLabel": [{
            "field": None,
            "color": [255, 255, 255],
            "size": 18,
            "offset": [0, 0],
            "anchor": "start",
            "alignment": "center"
          }]
        },
        "visualChannels": {
          "weightField": {
            "name": "Total canopy cover",
            "type": "real"
          },
          "weightScale": "linear"
        }
      }],
      "interactionConfig": {
        "tooltip": {
          "fieldsToShow": {
            "GEDI": ["Longitude", "Latitude", "height_bin0", "rh100", "Total canopy cover"]
          },
          "enabled": True
        },
        "brush": {
          "size": 0.5,
          "enabled": False
        }
      },
      "layerBlending": "normal",
      "splitMaps": [],
      "animationConfig": {
        "currentTime": None,
        "speed": 1
      }
    },
    "mapState": {
      "bearing": 24.733944954128447,
      "dragRotate": True,
      "latitude": 42.85182489603502,
      "longitude": -7.085374550112091,
      "pitch": 55.699414984242964,
      "zoom": 11.669849131811274,
      "isSplit": False
    },
    "mapStyle": {
      "styleType": "dark",
      "topLayerGroups": {},
      "visibleLayerGroups": {
        "label": True,
        "road": True,
        "border": False,
        "building": True,
        "water": True,
        "land": True,
        "3d building": False
      },
      "threeDBuildingColor": [9.665468314072013, 17.18305478057247, 31.1442867897876],
      "mapStyles": {}
    }
  }
}

# %%
map_1.add_data(data=df, name='GEDI')
map_1.config = config
map_1

# %%
map_1.save_to_html(file_name='gedi_viz.html')
